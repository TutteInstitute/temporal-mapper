# %% [markdown]
# ## Temporal Plots
# Temporal Mapper constructs a graph which does not have an inherent visualization. Moreover, if your data has $d$ semantic dimensions, then the graph 'naturally' lives in $d+1$ dimensions when including time.
#
# A temporal plot of a `TemporalMapper` is a 2d plot where the $x$-axis of a vertex is the median time of its corresponding cluster. For the $y$-axis, you can either pass a 1d reduction of your data or you can use an optimization algorithm to minimize the number of edge crossings.

# %% [markdown]
# Let's demonstrate a Temporal Plot by fitting a `TemporalMapper` to a small dataset of 10,000 arXiv machine learning papers. The paper's titles and abstracts were concatenated and embedded using the sentence transformer [all-mpnet-base-v2](https://huggingface.co/sentence-transformers/all-mpnet-base-v2), and then reduced to 2D with UMAP.

# %%
import temporalmapper as tm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests, io
from fast_hdbscan import HDBSCAN

# %%
response = requests.get(
    'https://github.com/TutteInstitute/temporal-mapper/raw/refs/heads/docs/docs/data/ai_arxiv_coordinates.npy'
)
map_data = np.load(io.BytesIO(response.content))

response = requests.get(
    'https://github.com/TutteInstitute/temporal-mapper/raw/refs/heads/docs/docs/data/ai_arxiv_data.feather'
)
df = pd.read_feather(io.BytesIO(response.content))

df.head()
# Out:
#                                                title  \
# 0  automated rating of recorded classroom present...
# 1       accelerating deep learning with memcomputing
# 2       accelerating deep learning with memcomputing
# 3  accurate reconstruction of image stimuli from ...
# 4                deep learning: a critical appraisal
#
#                                             abstract          id     created  \
# 0  effective presentation skills can help to succ...  1801.00453  2018-01-01
# 1  restricted boltzmann machines (rbms) and their...  1801.00512  2018-01-01
# 2  restricted boltzmann machines (rbms) and their...  1801.00512  2018-01-01
# 3  in neuroscience, all kinds of computation mode...  1801.00602  2018-01-02
# 4  although deep learning has historical roots go...  1801.00631  2018-01-02
#
#                                              authors  arxiv  \
# 0  [akzharkyn izbassarova, aidana irmanova, a. p....  cs.ai
# 1  [haik manukian, fabio l. traversa, massimilian...  cs.ai
# 2  [haik manukian, fabio l. traversa, massimilian...  cs.lg
# 3  [kai qiao, chi zhang, linyuan wang, bin yan, j...  cs.ai
# 4                                      [gary marcus]  cs.lg
#
#                            doi
# 0  10.1109/icacci.2017.8125872
# 1
# 2
# 3
# 4

# %%
# Compute a time column T which is the number of days since Jan 01, 2018.
def date_to_T(date):
    d0 = pd.Timestamp('2018-01-01')
    delta = date-d0
    return delta.days

df["date"] = pd.to_datetime(df["created"])
df["T"] = df["date"].apply(
    lambda x: date_to_T(x)
)
time = df["T"].to_numpy().reshape(-1,1)

# %%
clusterer = HDBSCAN(
    cluster_selection_method='eom',
    min_cluster_size=15,
)
mapper = tm.TemporalMapper(
    clusterer = clusterer,
    slice_method = 'data',
    n_slices = 8,
    kernel=tm.kernels.square
)

X = np.concatenate([map_data, time],axis=1)
mapper.fit(X)
# Out:
# TemporalMapper(clusterer=HDBSCAN(min_cluster_size=15),
#                data=array([[ 4.82239962, -1.57145286],
#        [ 1.20892036, -3.84591722],
#        [ 1.20193553, -3.85584664],
#        ...,
#        [11.05540466, 10.08293819],
#        [ 8.87438393, -1.76646364],
#        [11.04866219, 10.09112167]], shape=(10000, 2)),
#                n_slices=8, slice_method='data',
#                time=array([  0.,   0.,   0., ..., 480., 480., 480.], shape=(10000,)))

# %% [markdown]
# ### Static Temporal Plots

# %% [markdown]
# Now that we've fit a `TemporalMapper`, we can call its `temporal_plot` method which returns a matplotlib axis. By default, each vertex is labeled with `t:c` where `t` is the index of the temporal slice of the vertex, and `c` is the cluster number within that slice.

# %%
mapper.temporal_plot()
# Out:
# <Axes: >

# %% [markdown]
# There are a couple layout options that can be chosen.
# * Barycenter - Non deterministic optimization, quick and decent results.
# * Semantic - Accepts a `y_values` parameter for the points of the dataset and plots each vertex on its median value. If no `y_value` is passed, it uses the angle for 2d data and PCA to 1d for 3d+.
# * Ordered - Custom made layout function for typical temporal mapper graphs. Best results but can be slow on large graphs (like 100s of vertices).
#
# By default, ordered is used when the graph has under 100 vertices, and barycenter is used otherwise.

# %%
mapper.temporal_plot(layout='ordered')
# Out:
# <Axes: >

# %% [markdown]
# The optional `ax` argument allows you to pass a pre-made matplotlib axis, allowing you to add additional information to the plot as you wish.
#
# We can also use the `generate_keyword_labels` function from `temporalmapper.plotting` to generate some keywords to use as labels for the vertices. This function takes a bag-of-words for each datapoint as input. To keep it simple, we'll split the abstract and title on spaces, this won't give great labels, but its better than nothing.

# %%
from sklearn.decomposition import PCA
from datetime import datetime, timedelta

## Generate informative keywords
content = (df['title']+df['abstract']).to_numpy()
word_bags = []
for c in content:
    word_bags.append(c.split(" "))

cluster_labels = tm.plotting.generate_keyword_labels(word_bags, mapper, sep='\n')

## Create Temporal Plot
fig, ax = plt.subplots(1,1)
mapper.temporal_plot(
    ax=ax,
    cluster_labels=cluster_labels,
    cluster_label_kwargs={"fontsize":6},
    layout='ordered',
)
label_times = mapper.midpoints
label_dates = [
    (pd.Timestamp('2018-01-01')+timedelta(days=int(x))).strftime('%Y-%m')
     for x in label_times
]
ax.set_xticks(label_times,labels=label_dates)
ax.tick_params(axis='x', labelrotation=90)
fig.set_figwidth(10)
fig.set_figheight(8)
ax.set_title("Topics in ar$\chi$iv AI papers, 2018-2019")
ax.tick_params(bottom=True, labelbottom=True)
plt.show()
# Out:
# Generating keywords: 100%|██████████| 8/8 [00:00<00:00,  8.80it/s]

# %% [markdown]
# As you can see, for any appreciably complex dataset, the full Mapper graph will be hard to interpret. Instead, we can plot subgraphs. To plot the subgraph spanned by a list of vertices, `s`, you can pass the list to `temporal_plot` with `vertices=s`.
#
# For example, `TemporalMapper.vertex_subgraph(node)` will return the subgraph spanned by all the ancestors and descendants of `node`.

# %%
mapper.vertex_subgraph('4:12')
# Out:
# array(['0:23', '0:24', '1:16', '2:10', '3:14', '3:15', '4:12', '5:13',
#        '6:24', '6:25', '7:9'], dtype='<U4')

# %% [markdown]
# We can pass this to the plotting function to see just this subgraph.

# %%
from sklearn.decomposition import PCA
from datetime import datetime, timedelta

y_axis =  PCA(n_components=1).fit_transform(mapper.data)

fig, ax = plt.subplots(1,1)


mapper.temporal_plot(
    ax=ax,
    vertices=mapper.vertex_subgraph('4:12'),
    cluster_labels=cluster_labels,
    cluster_label_kwargs={"fontsize":10},
)

ax.tick_params(bottom=True, labelbottom=True)
fig.set_figwidth(10)
fig.set_figheight(8)
plt.show()

# %% [markdown]
# The `temporal_plot` uses `networkx`'s plotting functions, `draw_networkx_nodes` and `draw_networkx_edges`. If you want to further customize the look of the plot, you can pass dictionaries `node_kwargs` and `edge_kwargs` that will be passed along to these functions.
#
# Other notable customizations are:
#
# ```
# edge_scaling : float, default 1
#     Scaling factor applied to edge weights or widths.
# node_scaling : float, default 1
#     Scaling factor applied to node sizes.
# node_size_bounds :  tuple[float], default (5,25)
#     Size bounds to clip the node sizes to.
# edge_weight_bounds : tuple[float], default (0.1,1)
#     Size bounds to clip the edge thicknesses to.
# node_size_scale : {'linear', 'log', 'sigmoid'}, default 'sigmoid'
#     Scaling mode used for node sizes.
# ```

# %% [markdown]
# ### Interactive Temporal Plot
#
# Even better than plotting subgraphs, we can generate an interactive temporal plot using Plotly.

# %%
import plotly.io as pio
pio.renderers.default = 'sphinx_gallery'

mapper.interactive_temporal_plot()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="c8efa78f-4cae-4305-b048-e0863d2b56f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c8efa78f-4cae-4305-b048-e0863d2b56f3")) {                    Plotly.newPlot(                        "c8efa78f-4cae-4305-b048-e0863d2b56f3",                        [{"hoverinfo":"none","line":{"color":"#006044","width":1.0},"mode":"lines","x":[118.84848484848484,136.375,null],"y":[-0.7133350904924347,-0.7133536442603841,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#740000","width":1.0},"mode":"lines","x":[105.28571428571429,122.9,null],"y":[0.7399487523659102,0.7399487434705466,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#006f92","width":1.0},"mode":"lines","x":[84.8,136.56756756756758,null],"y":[1.1428184300372906,1.142856884165526,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#0065ae","width":1.0},"mode":"lines","x":[123.11764705882354,136.56756756756758,null],"y":[1.1428184277331264,1.142856884165526,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#9c0053","width":1.0},"mode":"lines","x":[76.3157894736842,145.79166666666666,null],"y":[0.3608504250193079,0.3603308140704154,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#90006c","width":1.0},"mode":"lines","x":[106.5625,140.6875,null],"y":[-0.6529662609707078,-0.6529662637938961,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#007822","width":1.0},"mode":"lines","x":[104.40322580645162,128.42857142857142,null],"y":[-1.2255344884208372,-1.2346468031524562,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#007822","width":1.0},"mode":"lines","x":[104.40322580645162,140.0,null],"y":[-1.2255344884208372,-1.234646803897158,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#bd2654","width":1.0},"mode":"lines","x":[109.74074074074075,145.79166666666666,null],"y":[0.36085042802939427,0.3603308140704154,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#c5472a","width":1.0},"mode":"lines","x":[76.35483870967742,129.8,null],"y":[1.8127022705505527,1.8127043110776293,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#009ec8","width":1.0},"mode":"lines","x":[88.5111111111111,145.2127659574468,null],"y":[-0.5782622198205365,-0.5782622132301075,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#0068c5","width":1.0},"mode":"lines","x":[95.5,145.2127659574468,null],"y":[-0.5782622229734445,-0.5782622132301075,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#7b5f00","width":1.0},"mode":"lines","x":[69.42857142857143,142.5121951219512,null],"y":[-0.2558545778984425,-0.25585456662072364,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#3a6900","width":1.0},"mode":"lines","x":[77.4,151.47058823529412,null],"y":[1.800509354775101,1.8259737469727444,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#009e64","width":1.0},"mode":"lines","x":[99.57142857142857,124.875,null],"y":[0.902536397619248,0.9025363812648702,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#9a00a9","width":1.0},"mode":"lines","x":[115.27272727272727,123.44,null],"y":[-1.0438081607663983,-1.0438081516493345,null],"type":"scatter","marker":{"showscale":false}},{ ...

# %% [markdown]
# The interactive plot is not as customizable as the static plot, but you can still make some customizations:

# %%
from plotly.graph_objects import Layout

mapper.interactive_temporal_plot(
    hover_text=cluster_labels,
    graph_layout=Layout(
        title=dict(text="Topics in arXiv AI papers, 2018-2019"),
        width=1000,
        height=600,
        showlegend=False,
    )
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="afbace89-a84c-496a-842d-257ca4794ee5" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("afbace89-a84c-496a-842d-257ca4794ee5")) {                    Plotly.newPlot(                        "afbace89-a84c-496a-842d-257ca4794ee5",                        [{"hoverinfo":"none","line":{"color":"#006044","width":1.0},"mode":"lines","x":[118.84848484848484,136.375,null],"y":[-0.7147677181640079,-0.7148374910538253,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#740000","width":1.0},"mode":"lines","x":[105.28571428571429,122.9,null],"y":[-0.7552586182864829,-0.7552586398364007,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#006f92","width":1.0},"mode":"lines","x":[84.8,136.56756756756758,null],"y":[-0.48051641240854687,-0.48056771204316,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#0065ae","width":1.0},"mode":"lines","x":[123.11764705882354,136.56756756756758,null],"y":[-0.4805163934247891,-0.48056771204316,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#9c0053","width":1.0},"mode":"lines","x":[76.3157894736842,145.79166666666666,null],"y":[0.42784308704080104,0.4281577588798059,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#90006c","width":1.0},"mode":"lines","x":[106.5625,140.6875,null],"y":[1.0633875780446485,1.0633875916570785,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#007822","width":1.0},"mode":"lines","x":[104.40322580645162,128.42857142857142,null],"y":[0.8442536222054827,0.8374535880593502,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#007822","width":1.0},"mode":"lines","x":[104.40322580645162,140.0,null],"y":[0.8442536222054827,0.8374535787360576,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#bd2654","width":1.0},"mode":"lines","x":[109.74074074074075,145.79166666666666,null],"y":[0.42784308264918486,0.4281577588798059,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#c5472a","width":1.0},"mode":"lines","x":[76.35483870967742,129.8,null],"y":[1.1855374537202905,1.1855258853816153,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#009ec8","width":1.0},"mode":"lines","x":[88.5111111111111,145.2127659574468,null],"y":[-1.0997221550380267,-1.0997221619309068,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#0068c5","width":1.0},"mode":"lines","x":[95.5,145.2127659574468,null],"y":[-1.0997221410485967,-1.0997221619309068,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#7b5f00","width":1.0},"mode":"lines","x":[69.42857142857143,142.5121951219512,null],"y":[1.443489859180884,1.4434898576954116,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#3a6900","width":1.0},"mode":"lines","x":[77.4,151.47058823529412,null],"y":[-0.9633354382309982,-0.9479931373586287,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#009e64","width":1.0},"mode":"lines","x":[99.57142857142857,124.875,null],"y":[1.3303530834551294,1.3303531134596234,null],"type":"scatter","marker":{"showscale":false}},{"hoverinfo":"none","line":{"color":"#9a00a9","width":1.0},"mode":"lines","x":[115.27272727272727,123.44,null],"y":[0.6859037554900009,0.6859037708854645,null],"type":"scatter","marker":{"showscale":false}}, ...
